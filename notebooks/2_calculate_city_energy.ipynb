# %%
# === Imports and config ===
import os
import warnings
import math
import time
import glob
import json
import gc
from collections import defaultdict

import numpy as np
import pandas as pd

import pvlib
from pvlib.location import Location
from pvlib.modelchain import ModelChain
from pvlib.pvsystem import PVSystem
from pvlib.temperature import TEMPERATURE_MODEL_PARAMETERS

# Rutas principales
MASTER_CSV = "solar_weather_all_cities.csv"   # generated in phase 1
RESULTS_DIR = "results"                       #  .pkl per city with AC/DC ratios series
RESULTS_SUMMARY = "results_summary.csv"       # yearly summary per city/ILR (append)
F_CAL_CSV = "pvgis_calibration_28cities.csv"   # f_cal per city (output of PVGIS calibration script)

os.makedirs(RESULTS_DIR, exist_ok=True)

# Control
CHUNKSIZE = 250_000       # rows per chunk to read master CSV without running out of RAM
TZ = "UTC"                # Timezone
PRINT_EVERY = 1           # Simple logging

# %%
# === Celda 2: Coordinates and plant configuration ===

# Build coord_df reading only city, lat, lon from master CSV
def build_coord_df_from_master(master_csv, chunksize=250_000):
    cols = ["city", "lat", "lon"]
    seen = {}
    for chunk in pd.read_csv(master_csv, usecols=cols, chunksize=chunksize):
        # Keep first occurrence of city
        for city, lat, lon in zip(chunk["city"], chunk["lat"], chunk["lon"]):
            if city not in seen:
                seen[city] = (lat, lon)
    if not seen:
        raise ValueError(f"No se encontraron ciudades en {master_csv}")

    df = pd.DataFrame(
        [(c, v[0], v[1]) for c, v in seen.items()],
        columns=["city", "latitude", "longitude"]
    ).set_index("city").sort_index()
    return df

# Create coord_df from master CSV
coord_df = build_coord_df_from_master(MASTER_CSV)
display(coord_df.head())

# Silence warning duplicate from pvlib
warnings.filterwarnings(
    "ignore",
    message=".*duplicate.*",
    category=UserWarning,
    module="pvlib.pvsystem"
)

# PV plant configuration
def plant_configuration():
    """
    common Config for all locations (NREL CEC).
    Returns:
      - df_ILR_power: Power and ILR table
      - inverter: inverter values
      - module: Module values
    """
    url_inverter = 'https://raw.githubusercontent.com/NREL/SAM/develop/deploy/libraries/CEC%20Inverters.csv'
    url_modules  = 'https://raw.githubusercontent.com/NREL/SAM/patch/deploy/libraries/CEC%20Modules.csv'

    cec_inverter = pvlib.pvsystem.retrieve_sam(path=url_inverter)
    cec_modules  = pvlib.pvsystem.retrieve_sam(path=url_modules)

    # Equipment selection
    inverter = cec_inverter['Chint_Power_Systems_America__CPS_SCH350KTL_DO_US_800__800V_']
    module   = cec_modules['Chint_New_Energy_Technology_Co__Ltd__CHSM66M_DG__F_BH_635']

    # Config del sistema
    n_inv = 143
    n_modules_per_strings = 26
    n_strings = np.arange(21.2, 60.3, 1.0)

    P_AC_inverter_MVA  = inverter.Paco
    P_DC_module_STC     = module.STC

    P_AC_output_power_inverter_MVA = n_inv * P_AC_inverter_MVA / 1e6
    P_DC_input_power_inverter_MWp  = n_inv * P_DC_module_STC * n_modules_per_strings * n_strings / 1e6
    ILR = P_DC_input_power_inverter_MWp / P_AC_output_power_inverter_MVA

    df_ILR_power = pd.DataFrame({
        'ILR': np.round(ILR, 2),
        'P_DC_input_power_inverter_MWp': np.round(P_DC_input_power_inverter_MWp, 2),
        'P_AC_output_power_inverter_MVA': P_AC_output_power_inverter_MVA,
        'num_inversores': n_inv,
        'num_strings': n_strings,
        'num_modules_per_string': n_modules_per_strings
    })

    return df_ILR_power, inverter, module

# Prepare config
temperature_parameters = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']
df_ILR_power, inverter, module = plant_configuration()

#Output variables
ILR_round = df_ILR_power['ILR'].values
P_DC_input_power_inverter_MWp = df_ILR_power['P_DC_input_power_inverter_MWp'].values
P_AC_output_power_inverter_MVA = df_ILR_power['P_AC_output_power_inverter_MVA'].iloc[0]
# Out:
#             latitude  longitude
# city
# Amsterdam   52.36760   4.904100
# Athens      37.98380  23.727500
# Berlin      52.52281  13.408176
# Bratislava  48.14860  17.107700
# Brussels    50.85030   4.351700

# %%
# === Load PVGIS calibration factors (f_cal per city) ===

f_cal_df = pd.read_csv(F_CAL_CSV)

# Build dict {city: f_cal}.  La columna se llama 'k_cal' en el CSV pero
# internamente la referimos como f_cal (location-specific yield correction factor).
f_cal_dict = dict(zip(f_cal_df['city'], f_cal_df['k_cal']))

# Sanity check: all 28 cities must have f_cal
missing = set(coord_df.index) - set(f_cal_dict.keys())
if missing:
    raise ValueError(f"Faltan f_cal para las ciudades: {sorted(missing)}")

print(f"✔ f_cal cargado para {len(f_cal_dict)} ciudades.")
print(f"  Rango: {min(f_cal_dict.values()):.4f} - {max(f_cal_dict.values()):.4f}")
print(f"  Mediana: {np.median(list(f_cal_dict.values())):.4f}")
# Out:
# ✔ f_cal cargado para 28 ciudades.
#   Rango: 1.0633 - 1.2701
#   Mediana: 1.1386

# %%
# === Save Plant configuration ===
import json

CONFIG_DIR = "plant_config"
os.makedirs(CONFIG_DIR, exist_ok=True)

# Tables -> CSV
coord_df.to_csv(os.path.join(CONFIG_DIR, "coord_df.csv"))                    # city, latitude, longitude
df_ILR_power.to_csv(os.path.join(CONFIG_DIR, "df_ILR_power.csv"), index=False)

# Series -> JSON 
with open(os.path.join(CONFIG_DIR, "inverter.json"), "w", encoding="utf-8") as f:
    json.dump(inverter.to_dict(), f, indent=2, default=float)
with open(os.path.join(CONFIG_DIR, "module.json"), "w", encoding="utf-8") as f:
    json.dump(module.to_dict(), f, indent=2, default=float)

# Temperature model parameters -> JSON
with open(os.path.join(CONFIG_DIR, "temperature_parameters.json"), "w", encoding="utf-8") as f:
    json.dump(temperature_parameters, f, indent=2, default=float)

# Configuration output
meta = {
    "P_AC_output_power_inverter_MW": float(P_AC_output_power_inverter_MVA),
    "n_inv": int(df_ILR_power["num_inversores"].iloc[0]),
    "n_modules_per_string": int(df_ILR_power["num_modules_per_string"].iloc[0]),
    "strings_min": float(df_ILR_power["num_strings"].min()),
    "strings_max": float(df_ILR_power["num_strings"].max()),
    "inverter_key": getattr(inverter, "name", None),
    "module_key": getattr(module, "name", None),
}
with open(os.path.join(CONFIG_DIR, "meta.json"), "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2, default=float)

print("✔ Configuración guardada en:", os.path.abspath(CONFIG_DIR))
# Out:
# ✔ Configuración guardada en: C:\Users\danie\PycharmProjects\solarPV\plant_config

# %%
# === Multipurpose functions ===

def validate_master(master_csv=MASTER_CSV, chunksize=CHUNKSIZE):
    """ Validate columns and parse 'time' """
    required = {"time","ghi","dni","dhi","wind_speed","temp_air","city","lat","lon"}
    try:
        hdr = pd.read_csv(master_csv, nrows=1)
    except Exception as e:
        raise RuntimeError(f"No se pudo leer {master_csv}: {e}")
    missing = required - set(hdr.columns)
    if missing:
        raise ValueError(f"Faltan columnas en {master_csv}: {sorted(missing)}")
    # Time parse
    for ch in pd.read_csv(master_csv, usecols=list(required), chunksize=chunksize):
        t = pd.to_datetime(ch["time"], utc=True, errors="coerce")
        if t.isna().any():
            raise ValueError("Hay filas con 'time' no parseable a datetime.")
        break
    print(f"✔ {master_csv} validado (muestra OK).")

def city_results_path(city):
    """Results Filepath per city (pickle)."""
    safe_city = city.replace(" ", "_")
    return os.path.join(RESULTS_DIR, f"{safe_city}_results.pkl")

def city_results_exists(city):
    return os.path.exists(city_results_path(city))

def save_city_results(city, time_index, ac_list, dc_list, ilr_values):
    """
    Save results per city:
      - time_index: DatetimeIndex
      - ac_list / dc_list: lista of lists (une per ILR)
      - ilr_values: array/list with ILR values
    """
    df_out = pd.DataFrame(index=time_index)
    # AC_i y DC_i por ILR; nombres legibles
    for i, ilr in enumerate(ilr_values):
        df_out[f"AC_MW_ILR_{ilr}"] = ac_list[i].values
        df_out[f"DC_MW_ILR_{ilr}"] = dc_list[i].values
    df_out["city"] = city
    df_out.to_pickle(city_results_path(city))

def append_summary(city, time_index, ac_list, ilr_values):
    """
    Write/add yearly summary per ciudad and ILR to RESULTS_SUMMARY:
      columns: city, ILR, E_AC_MWh (minute-level aggregation /60), P_AC_nom_MVA
    """
    rows = []
    for i, ilr in enumerate(ilr_values):
        e_mwh = ac_list[i].sum() / 60.0  # MW-min → MWh
        rows.append({
            "city": city,
            "ILR": ilr,
            "E_AC_MWh": float(e_mwh),
            "P_AC_nom_MVA": float(P_AC_output_power_inverter_MVA)
        })
    df_sum = pd.DataFrame(rows)
    header = not os.path.exists(RESULTS_SUMMARY)
    df_sum.to_csv(RESULTS_SUMMARY, mode="a", header=header, index=False)

def load_city_from_master(city, path=MASTER_CSV, chunksize=CHUNKSIZE):
    """
    Read from the master CSV only the rows for 'city', in chunks (memory-efficient).
Return a DataFrame with a UTC datetime index and the following columns:
ghi, dni, dhi, wind_speed, temp_air, lat, lon, city.
    """
    parts = []
    cols_needed = ["time", "ghi", "dni", "dhi", "wind_speed", "temp_air", "city", "lat", "lon"]
    for i, chunk in enumerate(pd.read_csv(path, usecols=cols_needed, chunksize=chunksize)):
        sub = chunk.loc[chunk["city"] == city]
        if not sub.empty:
            # parse time to datetime with tz UTC
            t = pd.to_datetime(sub["time"], utc=True, errors="coerce")
            sub = sub.assign(time=t).dropna(subset=["time"])
            parts.append(sub[cols_needed])
        if (i+1) % PRINT_EVERY == 0:
            pass  # logging optional

    if not parts:
        raise ValueError(f"No se encontraron datos para la ciudad '{city}' en {path}")

    df = pd.concat(parts, ignore_index=True)
    df = df.sort_values("time").set_index("time")

    # tz UTC
    if df.index.tz is None:
        df.index = df.index.tz_localize(TZ)
    else:
        df.index = df.index.tz_convert(TZ)

    # Floats Downcast for memory savings
    for col in ["ghi","dni","dhi","wind_speed","temp_air","lat","lon"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce", downcast="float")

    return df

# %%
# === Celda 4: Simulación de una ciudad ===

def simulate_city(city, ilr_rows=None, write_summary=True, overwrite=False):
    """
    Run the full simulation for 'city'.

    ilr_rows: iterable of df_ILR_power indices (to limit ILR range if desired)

    write_summary: if True, append the annual summary to RESULTS_SUMMARY

    overwrite: if False and the city's .pkl file already exists, skip it.
    """
    if not overwrite and city_results_exists(city):
        print(f"⏭️  Saltando {city}: resultados ya existen ({city_results_path(city)})")
        return

    if city not in coord_df.index:
        raise ValueError(f"Coordenadas no encontradas para '{city}'")

    lat = coord_df.loc[city, 'latitude']
    lon = coord_df.loc[city, 'longitude']
    tilt = lat * 0.76 + 3.1
    surface_azimuth = 180

    print(f"📦 Cargando meteo+irradiancia de {city} desde {MASTER_CSV} ...")
    solar_weather_df = load_city_from_master(city)  # índice datetime tz-aware

    # Chequeo defensivo de columnas para pvlib
    need = {"ghi","dni","dhi","temp_air","wind_speed"}
    missing = need - set(solar_weather_df.columns)
    if missing:
        raise ValueError(f"Faltan columnas para pvlib en {city}: {sorted(missing)}")

    # pvlib awaits index tz-aware
    if solar_weather_df.index.tz is None:
        solar_weather_df.index = solar_weather_df.index.tz_localize(TZ)
    else:
        solar_weather_df.index = solar_weather_df.index.tz_convert(TZ)

    # Location
    site_location = Location(latitude=lat, longitude=lon, tz=TZ, altitude=0, name=city)

    # IlR range
    rows_to_sim = df_ILR_power.index if ilr_rows is None else ilr_rows

    ac_list = []
    dc_list = []
    ilr_vals = []

    for i in rows_to_sim:
        row = df_ILR_power.loc[i]
        strings = row['num_strings']
        n_inv = int(row['num_inversores'])
        n_modules_per_string = int(row['num_modules_per_string'])
        ilr = float(row['ILR'])

        system = PVSystem(
            surface_tilt=tilt,
            surface_azimuth=surface_azimuth,
            module_parameters=module,
            inverter_parameters=inverter,
            modules_per_string=n_modules_per_string,
            strings_per_inverter=strings,
            temperature_model_parameters=temperature_parameters
        )

        modelchain = ModelChain(system=system, location=site_location,
                                aoi_model='no_loss', spectral_model='no_loss')
        
        # Run the model on the weather dataframe
        modelchain.run_model(solar_weather_df)

        # === Defensive check: pvlib outputs must not be None ===
        if modelchain.results.dc is None or modelchain.results.ac is None:
            raise RuntimeError(
                f"{city} ILR={ilr}: pvlib returned None for DC/AC. "
                f"strings={strings}, modules_per_string={n_modules_per_string}"
            )

        # === Extract DC from pvlib ModelChain (robust to pvlib version) ===
        # In recent pvlib versions, results.dc can be either a DataFrame with 'p_mp'
        # column or a Series directly with DC power.
        dc_raw = modelchain.results.dc
        if isinstance(dc_raw, pd.DataFrame) and 'p_mp' in dc_raw.columns:
            dc_power_W = dc_raw['p_mp']
        elif isinstance(dc_raw, pd.Series):
            dc_power_W = dc_raw
        else:
            raise TypeError(
                f"Unexpected type for modelchain.results.dc in {city}: {type(dc_raw)}"
            )

        # === Apply location-specific PVGIS calibration factor (f_cal) ===
        # f_cal absorbs downstream system losses (soiling, cabling, mismatch, etc.).
        # Applied to both DC and AC, but AC is capped at inverter Paco to preserve
        # the physical clipping behaviour at high ILR values.
        f_cal = f_cal_dict[city]

        # DC power: scale by f_cal (no upper limit; array DC can exceed Paco at high ILR)
        dc = n_inv * dc_power_W / 1e6
        dc = (dc * f_cal).clip(lower=0)

        # AC power: scale by f_cal but respect inverter Paco limit
        P_AC_max_MW = (n_inv * inverter.Paco) / 1e6
        ac = n_inv * modelchain.results.ac / 1e6
        ac = (ac * f_cal).clip(lower=0, upper=P_AC_max_MW)

        ac_list.append(ac)
        dc_list.append(dc)
        ilr_vals.append(ilr)

        # Cleaning
        del modelchain
        gc.collect()

    # Incremental saving
    save_city_results(city, solar_weather_df.index, ac_list, dc_list, ilr_vals)
    if write_summary:
        append_summary(city, solar_weather_df.index, ac_list, ilr_vals)

    print(f"✅ Simulación completada: {city}  |  ILRs simulados: {len(ilr_vals)}")

# %%
# === Celda 5: Ejecución por lotes ===

def run_model_batch(target_cities=None, ilr_rows=None, overwrite=False):
    """
    Run batch simulations:

    target_cities: list of cities (if None, take all cities from coord_df that are present in MASTER_CSV)

    ilr_rows: iterable of df_ILR_power indices to simulate (for quick tests)

    overwrite: if False, do not recalculate cities that already have a .pkl created.
    """
    if target_cities is None:
        # Check cities in master file
        try:
            cities_in_master = set()
            for chunk in pd.read_csv(MASTER_CSV, usecols=["city"], chunksize=CHUNKSIZE):
                cities_in_master.update(chunk["city"].unique().tolist())
            target_cities = sorted(list(set(coord_df.index).intersection(cities_in_master)))
        except Exception as e:
            print(f"⚠️ No pude inferir ciudades del maestro: {e}")
            target_cities = list(coord_df.index)

    for c in target_cities:
        try:
            simulate_city(c, ilr_rows=ilr_rows, write_summary=True, overwrite=overwrite)
        except Exception as e:
            print(f"❌ Error en {c}: {e}")

# %%
# === Run examples ===

# 1) Validate master before running simulations
# validate_master()

# 2) Test one city with a few ILR rows (fast)
# run_model_batch(target_cities=["Madrid"], ilr_rows=df_ILR_power.index[:3])

# 3) Run a full city (all ILRs), resumable
# run_model_batch(target_cities=["Madrid"])

# 4) Run several cities in batches (resumable; skips if .pkl already exists)
# run_model_batch(target_cities=["Madrid", "Paris", "Berlin"])

# 5) Force recalculation of a city (overwrite)
# run_model_batch(target_cities=["Madrid"], overwrite=True)

# 6) Run all cities present in the master CSV:
# run_model_batch()

# %%
# === sanity check ===

# 1) Validate master
validate_master()
# Out:
# ✔ solar_weather_all_cities.csv validado (muestra OK).

# %%
run_model_batch()
# Out:
# 📦 Cargando meteo+irradiancia de Amsterdam desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Amsterdam  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Athens desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Athens  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Berlin desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Berlin  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Bratislava desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Bratislava  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Brussels desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Brussels  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Bucharest desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Bucharest  |  ILRs simulados: 40
# 📦 Cargando meteo+irradiancia de Budapest desde solar_weather_all_cities.csv ...
# ✅ Simulación completada: Budapest  |  ILRs simulados: 40
# ...

# %%
"""
Verificación rápida del sesgo entre CAMS y PVGIS-SARAH3.
Compara GHI anual reportado por ambas fuentes para varias ciudades europeas.

USO: Pegar como celda nueva en notebook 2_calculate_city_energy.ipynb,
DESPUÉS de la celda donde se carga coord_df.
También puede ejecutarse como script independiente si MASTER_CSV está disponible.

Tarda ~1 min (lee CSV + 5 llamadas API a PVGIS).
"""

import pandas as pd
import requests
import io


# ===== Ciudades a verificar =====
CITIES_TO_CHECK = ['Madrid', 'Paris', 'Berlin', 'Helsinki', 'Rome']


# ===== 1) GHI anual desde CAMS (tu dataset) =====
def get_cams_ghi_annual(city, master_csv="solar_weather_all_cities.csv", chunksize=250_000):
    """
    Lee el GHI anual promedio para 'city' desde el master CSV.
    Returns: (ghi_yearly_kWh_m2, n_years, lat, lon, dt_seconds)
    """
    parts = []
    for chunk in pd.read_csv(master_csv, usecols=["time", "ghi", "city", "lat", "lon"], chunksize=chunksize):
        sub = chunk.loc[chunk["city"] == city, ["time", "ghi", "lat", "lon"]]
        if not sub.empty:
            parts.append(sub)

    if not parts:
        raise ValueError(f"No se encontraron datos para {city}")

    df = pd.concat(parts, ignore_index=True)
    df["time"] = pd.to_datetime(df["time"], utc=True, errors="coerce")
    df = df.dropna(subset=["time", "ghi"])
    df = df.sort_values("time").reset_index(drop=True)

    lat = float(df["lat"].iloc[0])
    lon = float(df["lon"].iloc[0])

    # Detectar resolución temporal mirando la mediana de diffs (más robusto que [0]-[1])
    diffs = df["time"].diff().dropna().dt.total_seconds()
    dt_sec = float(diffs.median())

    n_years = df["time"].dt.year.nunique()

    # Integrar GHI a energía anual
    # GHI está en W/m². Energy = sum(GHI * dt) / 3600 / 1000 = kWh/m² acumulado
    # Anual = total / n_years
    total_kWh_m2 = (df["ghi"].sum() * dt_sec / 3600.0) / 1000.0
    ghi_yearly_kWh_m2 = total_kWh_m2 / n_years

    return ghi_yearly_kWh_m2, n_years, lat, lon, dt_sec


# ===== 2) GHI anual desde PVGIS-SARAH3 =====
def get_pvgis_ghi_annual(lat, lon, startyear=2020, endyear=2023):
    """
    Consulta PVGIS-SARAH3 vía API y devuelve GHI anual promedio en kWh/m²/año.
    Usa plano horizontal (angle=0, aspect=0) para obtener GHI directamente.
    """
    url = (
        f"https://re.jrc.ec.europa.eu/api/v5_3/seriescalc"
        f"?lat={lat}&lon={lon}"
        f"&startyear={startyear}&endyear={endyear}"
        f"&outputformat=csv"
        f"&angle=0&aspect=0"            # Plano horizontal → G(i) = GHI
        f"&raddatabase=PVGIS-SARAH3"
    )
    r = requests.get(url, timeout=60)
    r.raise_for_status()

    # PVGIS devuelve un CSV con preámbulo. Encontrar la cabecera real.
    lines = r.text.split('\n')
    header_idx = None
    for i, line in enumerate(lines):
        if line.startswith("time,"):
            header_idx = i
            break
    if header_idx is None:
        raise ValueError("Cabecera 'time,...' no encontrada en respuesta PVGIS")

    # Cortar el preámbulo y leer
    data_text = '\n'.join(lines[header_idx:])
    df = pd.read_csv(io.StringIO(data_text), low_memory=False)

    # Detectar nombre de la columna de irradiancia global en plano
    irr_col = None
    for cand in ['G(i)', 'G(h)', 'GHI']:
        if cand in df.columns:
            irr_col = cand
            break
    if irr_col is None:
        raise ValueError(f"Columna de irradiancia no encontrada. Columnas: {list(df.columns)}")

    # PVGIS pone metadatos al final que ensucian. Filtrar filas válidas por formato de time.
    df = df[df["time"].astype(str).str.match(r"^\d{8}", na=False)].copy()
    df["time"] = pd.to_datetime(df["time"], format="%Y%m%d:%H%M", errors="coerce")
    df = df.dropna(subset=["time"])

    df[irr_col] = pd.to_numeric(df[irr_col], errors="coerce")
    df = df.dropna(subset=[irr_col])

    n_years = df["time"].dt.year.nunique()
    # Datos horarios (PVGIS): suma directa en W/m² × 1h = Wh/m², dividir por 1000 para kWh/m²
    ghi_yearly_kWh_m2 = df[irr_col].sum() / 1000.0 / n_years

    return ghi_yearly_kWh_m2, n_years, irr_col


# ===== 3) Comparación =====
print("="*95)
print(f"{'City':<12} | {'CAMS GHI':<22} | {'PVGIS GHI':<22} | {'Diff':<10} | {'k_GHI':<10}")
print(f"{'':<12} | {'(kWh/m²/year)':<22} | {'(kWh/m²/year)':<22} | {'(%)':<10} | {'PVGIS/CAMS':<10}")
print("="*95)

results = []
for city in CITIES_TO_CHECK:
    try:
        cams_yearly, n_cams, lat, lon, dt_sec = get_cams_ghi_annual(city)
        pvgis_yearly, n_pvgis, irr_col = get_pvgis_ghi_annual(lat, lon)

        diff_pct = (pvgis_yearly - cams_yearly) / cams_yearly * 100
        k_ghi = pvgis_yearly / cams_yearly

        print(f"{city:<12} | {cams_yearly:7.1f} (n={n_cams}y, dt={dt_sec:>5.0f}s) | "
              f"{pvgis_yearly:7.1f} (n={n_pvgis}y, {irr_col}) | "
              f"{diff_pct:+7.2f}%  | {k_ghi:.4f}")

        results.append({
            "city": city, "lat": lat, "lon": lon,
            "cams_dt_seconds": dt_sec,
            "cams_ghi_kWh_m2_year": cams_yearly,
            "pvgis_ghi_kWh_m2_year": pvgis_yearly,
            "diff_pct": diff_pct,
            "k_ghi": k_ghi,
        })
    except Exception as e:
        print(f"{city:<12} | ERROR: {type(e).__name__}: {e}")

print("="*95)
print()
print("INTERPRETACIÓN:")
print("- Si k_GHI ≈ 1.00 (Diff ≈ 0%): CAMS y PVGIS coinciden en irradiancia →")
print("  el sesgo k_cal viene del MODELO PV (módulo CEC, parámetros, etc.)")
print("- Si k_GHI ≈ 1.10-1.15 (PVGIS reporta más): el sesgo k_cal es de la")
print("  FUENTE DE DATOS (CAMS subestima la irradiancia respecto a PVGIS-SARAH3)")
print("- Si k_GHI < 1.00: CAMS reporta más; el sesgo k_cal del modelo PV es mayor")
print("  de lo que parecía y CAMS lo compensaba parcialmente.")

# Save results
df_results = pd.DataFrame(results)
df_results.to_csv("cams_vs_pvgis_ghi_comparison.csv", index=False)
print("\n✓ Resultados guardados en: cams_vs_pvgis_ghi_comparison.csv")
# Out:
# ...
# City         | CAMS GHI               | PVGIS GHI              | Diff       | k_GHI
#              | (kWh/m²/year)          | (kWh/m²/year)          | (%)        | PVGIS/CAMS
# ...
# Madrid       |  1785.5 (n=1y, dt=   60s) |  1767.7 (n=4y, G(i)) |   -1.00%  | 0.9900
# Paris        |  1071.9 (n=1y, dt=   60s) |  1276.0 (n=4y, G(i)) |  +19.05%  | 1.1905
# Berlin       |  1118.3 (n=1y, dt=   60s) |  1130.6 (n=4y, G(i)) |   +1.10%  | 1.0110
# Helsinki     |  1013.7 (n=1y, dt=   60s) |  1025.3 (n=4y, G(i)) |   +1.14%  | 1.0114
# Rome         |  1666.2 (n=1y, dt=   60s) |  1662.6 (n=4y, G(i)) |   -0.22%  | 0.9978
# ...
#
# INTERPRETACIÓN:
# - Si k_GHI ≈ 1.00 (Diff ≈ 0%): CAMS y PVGIS coinciden en irradiancia →
#   el sesgo k_cal viene del MODELO PV (módulo CEC, parámetros, etc.)
# - Si k_GHI ≈ 1.10-1.15 (PVGIS reporta más): el sesgo k_cal es de la
#   FUENTE DE DATOS (CAMS subestima la irradiancia respecto a PVGIS-SARAH3)
# - Si k_GHI < 1.00: CAMS reporta más; el sesgo k_cal del modelo PV es mayor
# ...

# %%
"""
Script para verificar que el outlier de Paris se explica por la variabilidad
interanual de 2024 (año anómalo en Francia, no por sesgo CAMS).
 
Consulta PVGIS-SARAH3 año a año para Paris y compara con CAMS.
"""
 
import pandas as pd
import requests
import io
 
 
def get_pvgis_ghi_for_year(lat, lon, year):
    """GHI anual (kWh/m²/año) desde PVGIS-SARAH3 para un año concreto."""
    url = (
        f"https://re.jrc.ec.europa.eu/api/v5_3/seriescalc"
        f"?lat={lat}&lon={lon}"
        f"&startyear={year}&endyear={year}"
        f"&outputformat=csv"
        f"&angle=0&aspect=0"
        f"&raddatabase=PVGIS-SARAH3"
    )
    r = requests.get(url, timeout=60)
    r.raise_for_status()
    lines = r.text.split('\n')
    header_idx = next(i for i, l in enumerate(lines) if l.startswith("time,"))
    df = pd.read_csv(io.StringIO('\n'.join(lines[header_idx:])), low_memory=False)
    df = df[df["time"].astype(str).str.match(r"^\d{8}", na=False)].copy()
    df["time"] = pd.to_datetime(df["time"], format="%Y%m%d:%H%M", errors="coerce")
    df = df.dropna(subset=["time"])
    irr_col = next(c for c in ['G(i)', 'G(h)', 'GHI'] if c in df.columns)
    df[irr_col] = pd.to_numeric(df[irr_col], errors="coerce")
    df = df.dropna(subset=[irr_col])
    return df[irr_col].sum() / 1000.0   # kWh/m²/año
 
 
# ===== Paris year by year =====
LAT, LON = 48.8566, 2.3522
 
print("=" * 65)
print("PARIS — GHI anual según PVGIS-SARAH3, año por año")
print("=" * 65)
 
results = []
for year in range(2018, 2024):
    try:
        ghi = get_pvgis_ghi_for_year(LAT, LON, year)
        results.append({"year": year, "ghi_kWh_m2": ghi})
        print(f"  {year}: {ghi:7.1f} kWh/m²/año")
    except Exception as e:
        print(f"  {year}: ERROR ({e})")
 
df = pd.DataFrame(results)
mean_4yr = df[df['year'].between(2020, 2023)]['ghi_kWh_m2'].mean()
mean_6yr = df['ghi_kWh_m2'].mean()
std_6yr = df['ghi_kWh_m2'].std()
 
print("=" * 65)
print(f"Promedio 2020-2023 (PVGIS reference window): {mean_4yr:.1f} kWh/m²/año")
print(f"Promedio 2018-2023 (6 años):                 {mean_6yr:.1f} kWh/m²/año")
print(f"Desviación estándar interanual (6 años):     {std_6yr:.1f} kWh/m²/año")
print(f"")
print(f"CAMS Paris 2024:                             1071.9 kWh/m²/año")
print(f"Desviación 2024 vs promedio 2020-2023:       "
      f"{(1071.9 - mean_4yr):+.1f} kWh/m²/año "
      f"({(1071.9 - mean_4yr) / mean_4yr * 100:+.1f}%)")
print(f"")
print(f"INTERPRETACIÓN:")
print(f"Si la diferencia 2024 vs 2020-2023 es mayor que ~1.5 std, el año")
print(f"es estadísticamente atípico. CAMS no tiene sesgo en Paris,")
print(f"simplemente captura un año mal año atípicamente nublado.")
# Out:
# ...
# PARIS — GHI anual según PVGIS-SARAH3, año por año
# ...
#   2018:  1275.4 kWh/m²/año
#   2019:  1274.0 kWh/m²/año
#   2020:  1297.0 kWh/m²/año
#   2021:  1210.9 kWh/m²/año
#   2022:  1333.4 kWh/m²/año
#   2023:  1231.2 kWh/m²/año
# ...
# Promedio 2020-2023 (PVGIS reference window): 1268.1 kWh/m²/año
# Promedio 2018-2023 (6 años):                 1270.3 kWh/m²/año
# Desviación estándar interanual (6 años):     44.3 kWh/m²/año
#
# CAMS Paris 2024:                             1071.9 kWh/m²/año
# Desviación 2024 vs promedio 2020-2023:       -196.2 kWh/m²/año (-15.5%)
#
# INTERPRETACIÓN:
# Si la diferencia 2024 vs 2020-2023 es mayor que ~1.5 std, el año
# es estadísticamente atípico. CAMS no tiene sesgo en Paris,
# simplemente captura un año mal año atípicamente nublado.

# %%
"""
Calcula el Performance Ratio (PR) efectivo del pipeline pvlib en Madrid.
Compara contra el PR teórico de PVGIS (que aplica 14% de system loss por defecto).

USO: Pegar como celda nueva en notebook 2_calculate_city_energy.ipynb,
o ejecutar como script en el mismo directorio donde están:
  - results/Madrid_results.pkl  (generado por simulate_city)
  - plant_config/df_ILR_power.csv  (generado por save plant config)

Tarda <30 segundos.
"""

import os
import re
import pandas as pd
import numpy as np
import requests
import io


# ===== Config =====
CITY = "Madrid"
LAT, LON = 40.42, -3.70
RESULTS_DIR = "results"
CONFIG_DIR = "plant_config"


# ===== 1) Cargar resultados del pipeline pvlib =====
def load_madrid_results():
    """Lee los datos AC/DC simulados de Madrid y la config de planta."""
    pkl_path = os.path.join(RESULTS_DIR, f"{CITY}_results.pkl")
    if not os.path.exists(pkl_path):
        raise FileNotFoundError(f"No existe {pkl_path}. Ejecuta primero run_model_batch(['Madrid']).")
    
    df = pd.read_pickle(pkl_path)
    df_ilr = pd.read_csv(os.path.join(CONFIG_DIR, "df_ILR_power.csv"))
    
    # Detectar columnas AC/DC por ILR
    ac_map, dc_map = {}, {}
    for c in df.columns:
        m_ac = re.fullmatch(r"AC_MW_ILR_([0-9.]+)", c)
        m_dc = re.fullmatch(r"DC_MW_ILR_([0-9.]+)", c)
        if m_ac: ac_map[float(m_ac.group(1))] = c
        if m_dc: dc_map[float(m_dc.group(1))] = c
    
    return df, df_ilr, ac_map, dc_map


# ===== 2) Calcular yields y PR para varios ILR =====
def compute_yields(df, df_ilr, ac_map, dc_map, target_ilrs=(1.0, 1.2, 1.4)):
    """
    Para los ILR objetivo más cercanos, calcula:
      - DC_energy_MWh anual
      - AC_energy_MWh anual
      - Yield específico (kWh/kWp/año)
      - PR efectivo
    """
    results = []
    
    # Detectar resolución temporal del índice (60s espera el pipeline)
    if len(df.index) >= 2:
        dt_seconds = (df.index[1] - df.index[0]).total_seconds()
    else:
        dt_seconds = 60.0
    
    n_years = df.index.year.nunique() if hasattr(df.index, 'year') else 1
    
    available_ilrs = sorted(ac_map.keys())
    
    for tgt_ilr in target_ilrs:
        # Buscar el ILR disponible más cercano
        closest_ilr = min(available_ilrs, key=lambda x: abs(x - tgt_ilr))
        ac_col = ac_map[closest_ilr]
        dc_col = dc_map[closest_ilr]
        
        # Potencia AC y DC nominales para ese ILR
        idx = (df_ilr["ILR"] - closest_ilr).abs().idxmin()
        P_DC_MWp = float(df_ilr.loc[idx, "P_DC_input_power_inverter_MWp"])
        P_AC_MW  = float(df_ilr.loc[idx, "P_AC_output_power_inverter_MVA"])
        
        # Energía anual integrando series (W·s → Wh)
        # Las series están en MW. Integral = MW * seconds = MJ.
        # MWh = MJ / 3600
        ac_MWh_total = df[ac_col].sum() * dt_seconds / 3600.0
        dc_MWh_total = df[dc_col].sum() * dt_seconds / 3600.0
        
        # Anual (si tienes varios años)
        ac_MWh_year = ac_MWh_total / n_years
        dc_MWh_year = dc_MWh_total / n_years
        
        # Yield específico (kWh/kWp/año)
        yield_specific = ac_MWh_year * 1000.0 / (P_DC_MWp * 1000.0)  # kWh/kWp/año
        
        # PR efectivo = yield_AC_real / yield_teórico_ideal
        # Necesitamos GHI o POA para el PR riguroso. Aproximación:
        # PR ≈ E_AC / (P_DC_STC × H_POA / G_STC)
        # Sin H_POA directo, usamos H_GHI como proxy
        
        # PR alternativo: ratio DC efectivo vs DC nominal
        # PR_DC = E_DC / (P_DC_STC × H_POA × hours)
        
        # Métrica intermedia útil: ratio AC/DC (eficiencia del inverter)
        ac_dc_ratio = ac_MWh_year / dc_MWh_year if dc_MWh_year > 0 else 0
        
        results.append({
            "ILR_target": tgt_ilr,
            "ILR_used": closest_ilr,
            "P_DC_MWp": P_DC_MWp,
            "P_AC_MW": P_AC_MW,
            "DC_energy_MWh_year": dc_MWh_year,
            "AC_energy_MWh_year": ac_MWh_year,
            "yield_AC_kWh_per_kWp": yield_specific,
            "AC_DC_ratio": ac_dc_ratio,
            "n_years": n_years,
            "dt_seconds": dt_seconds,
        })
    
    return pd.DataFrame(results)


# ===== 3) Consultar PVGIS para Madrid con sistema completo =====
def query_pvgis_pv_madrid(lat, lon, peakpower_kw=1.0, loss_pct=14, tilt=33.8):
    """
    Consulta PVGIS-SARAH3 con cálculo PV completo.
    Devuelve yield específico (kWh/kWp/año) y PR teórico.
    
    PVGIS-SARAH3 datos disponibles: 2005-2023
    """
    url = (
        f"https://re.jrc.ec.europa.eu/api/v5_3/PVcalc"
        f"?lat={lat}&lon={lon}"
        f"&peakpower={peakpower_kw}"
        f"&loss={loss_pct}"
        f"&angle={tilt}&aspect=0"
        f"&raddatabase=PVGIS-SARAH3"
        f"&pvtechchoice=crystSi"
        f"&mountingplace=free"
        f"&outputformat=json"
    )
    r = requests.get(url, timeout=60)
    r.raise_for_status()
    data = r.json()
    
    # Estructura: outputs > totals > fixed
    fixed = data["outputs"]["totals"]["fixed"]
    
    # E_y = yield anual (kWh / yr / kWp)
    # H(i)_y = irradiancia anual en plano (kWh/m²/yr)
    # SD_y = std of E_y (interannual variability)
    
    E_y_annual_yield = fixed["E_y"]            # kWh/kWp/año (con 14% loss aplicado)
    H_i_annual_irrad = fixed["H(i)_y"]         # kWh/m²/año en plano
    
    # PR de PVGIS = E_y / H_i_y (despreciando temperature derate del módulo, 
    # que ya está incluido en E_y porque PVGIS lo calcula)
    PR_pvgis = E_y_annual_yield / H_i_annual_irrad
    
    return {
        "E_y_kWh_per_kWp_year": E_y_annual_yield,
        "H_i_kWh_per_m2_year": H_i_annual_irrad,
        "PR_pvgis": PR_pvgis,
        "loss_assumed_pct": loss_pct,
    }


# ===== 4) Ejecutar y comparar =====
print("="*80)
print(f"DIAGNÓSTICO DEL SESGO EN EL MODELO PV — {CITY}")
print("="*80)

# 4a) Resultados del pipeline pvlib
print("\n--- TU PIPELINE pvlib (CAMS) ---")
df, df_ilr, ac_map, dc_map = load_madrid_results()
yields = compute_yields(df, df_ilr, ac_map, dc_map, target_ilrs=(1.0, 1.2, 1.4))
print(yields.to_string(index=False))

# 4b) PVGIS con system loss 14% (default)
print(f"\n--- PVGIS-SARAH3 (system loss = 14%, tilt={33.8}°, sur) ---")
try:
    # tilt según el código original: lat * 0.76 + 3.1 = 33.82 para Madrid
    tilt_madrid = round(LAT * 0.76 + 3.1, 1)
    pvgis = query_pvgis_pv_madrid(LAT, LON, peakpower_kw=1.0, loss_pct=14, tilt=tilt_madrid)
    for k, v in pvgis.items():
        if isinstance(v, float):
            print(f"  {k}: {v:.3f}")
        else:
            print(f"  {k}: {v}")
except Exception as e:
    print(f"Error consultando PVGIS: {e}")
    pvgis = None

# 4c) Comparativa final
if pvgis is not None and len(yields) > 0:
    print("\n" + "="*80)
    print("COMPARATIVA CUANTITATIVA")
    print("="*80)
    
    ilr_1_row = yields[yields["ILR_target"] == 1.0].iloc[0]
    yield_pvlib = ilr_1_row["yield_AC_kWh_per_kWp"]
    yield_pvgis = pvgis["E_y_kWh_per_kWp_year"]
    
    diff_pct = (yield_pvgis - yield_pvlib) / yield_pvlib * 100
    k_implied = yield_pvgis / yield_pvlib
    
    print(f"\n{'Métrica':<40} {'Tu pipeline':>15} {'PVGIS-SARAH3':>15}")
    print("-"*80)
    print(f"{'Yield específico AC (kWh/kWp/año)':<40} {yield_pvlib:>15.1f} {yield_pvgis:>15.1f}")
    print(f"{'Diferencia (%)':<40} {' ':<15} {diff_pct:>+15.2f}")
    print(f"{'k_implied = PVGIS/pvlib':<40} {' ':<15} {k_implied:>15.4f}")
    
    print(f"\nk_cal observado en tu calibración: 1.1584 (Madrid)")
    print(f"k_implied calculado ahora:         {k_implied:.4f}")
    print(f"\nSi ambos coinciden (±2%), el diagnóstico está confirmado:")
    print(f"El sesgo ~14% del modelo proviene de pérdidas de sistema no modeladas")
    print(f"(soiling, cabling, mismatch, etc.) que PVGIS aplica por defecto y")
    print(f"tu pipeline pvlib no aplica.")
# Out:
# ...
# DIAGNÓSTICO DEL SESGO EN EL MODELO PV — Madrid
# ...
#
# --- TU PIPELINE pvlib (CAMS) ---
#  ILR_target  ILR_used  P_DC_MWp  P_AC_MW  DC_energy_MWh_year  AC_energy_MWh_year  yield_AC_kWh_per_kWp  AC_DC_ratio  n_years  dt_seconds
#         1.0      1.00     50.09    50.05        71105.814111        69845.037753           1394.390852     0.982269        1        60.0
#         1.2      1.19     59.54    50.05        84522.005453        82883.618267           1392.066145     0.980616        1        60.0
#         1.4      1.38     69.00    50.05        97938.196795        94022.131415           1362.639586     0.960015        1        60.0
#
# --- PVGIS-SARAH3 (system loss = 14%, tilt=33.8°, sur) ---
#   E_y_kWh_per_kWp_year: 1617.600
#   H_i_kWh_per_m2_year: 2091.770
#   PR_pvgis: 0.773
#   loss_assumed_pct: 14
#
# ...
# COMPARATIVA CUANTITATIVA
# ...
#
# Métrica                                      Tu pipeline    PVGIS-SARAH3
# ...

# %%
# === Sanity check final: las 28 ciudades calibradas ===

import os

P_AC_max_MW = df_ILR_power['P_AC_output_power_inverter_MVA'].iloc[0]

print(f"{'City':<15} {'Yield (kWh/kWp)':>16} {'Max AC (MW)':>14} {'Paco resp.':>12}")
print("-" * 60)

results_summary = []

for city in sorted(coord_df.index):
    pkl_path = city_results_path(city)
    if not os.path.exists(pkl_path):
        print(f"{city:<15} ❌ NO PKL")
        continue
    
    df_city = pd.read_pickle(pkl_path)
    ac_cols = [c for c in df_city.columns if c.startswith('AC_MW_ILR_')]
    
    # Encontrar ILR más cercano a 1.0
    ilrs = sorted([float(c.replace('AC_MW_ILR_', '')) for c in ac_cols])
    closest = min(ilrs, key=lambda x: abs(x - 1.0))
    ac_col = f'AC_MW_ILR_{closest}'
    
    # Yield específico (kWh/kWp/año)
    ac_MWh = df_city[ac_col].sum() / 60.0
    P_DC = df_ILR_power.loc[df_ILR_power['ILR'] == closest, 'P_DC_input_power_inverter_MWp'].values[0]
    yield_city = ac_MWh / P_DC
    
    # Max AC across all ILRs
    max_ac = max(df_city[c].max() for c in ac_cols)
    paco_ok = "✅" if max_ac <= P_AC_max_MW * 1.001 else "⚠️"
    
    results_summary.append({"city": city, "yield": yield_city, "max_ac": max_ac, "ok": paco_ok})
    print(f"{city:<15} {yield_city:>16.1f} {max_ac:>14.3f} {paco_ok:>12}")

# Stats
yields = [r['yield'] for r in results_summary]
print(f"\n{'='*60}")
print(f"Rango yields: {min(yields):.1f} - {max(yields):.1f} kWh/kWp/año")
print(f"Mediana: {np.median(yields):.1f} kWh/kWp/año")
print(f"Media:   {np.mean(yields):.1f} kWh/kWp/año")
print(f"Ciudades procesadas: {len(results_summary)}/28")

# Check violaciones Paco
violations = [r for r in results_summary if r['ok'] == "⚠️"]
if violations:
    print(f"\n⚠️  {len(violations)} ciudades con max AC > Paco. REVISAR.")
    for v in violations:
        print(f"   - {v['city']}: max AC = {v['max_ac']:.3f} MW")
else:
    print(f"\n✅ Todas las {len(results_summary)} ciudades respetan el límite Paco.")

# Cross-check con PVGIS calibration CSV
print(f"\n{'='*60}")
print(f"Cross-check: yields calibrados vs PVGIS reference")
print(f"{'='*60}")
print(f"{'City':<15} {'Yield calibrado':>16} {'PVGIS ref':>12} {'Diff':>10}")
print("-" * 55)

cal_df = pd.read_csv(F_CAL_CSV)
for r in results_summary:
    city = r['city']
    pvgis_ref = cal_df.loc[cal_df['city'] == city, 'pvgis_yield_kWh_per_kWp'].values
    if len(pvgis_ref) > 0:
        pvgis_val = pvgis_ref[0]
        diff_pct = (r['yield'] - pvgis_val) / pvgis_val * 100
        print(f"{city:<15} {r['yield']:>16.1f} {pvgis_val:>12.1f} {diff_pct:>+9.2f}%")
# Out:
# City             Yield (kWh/kWp)    Max AC (MW)   Paco resp.
# ------------------------------------------------------------
# Amsterdam                 1023.3         50.050            ✅
# Athens                    1571.7         50.050            ✅
# Berlin                    1049.1         50.050            ✅
# Bratislava                1204.0         50.050            ✅
# Brussels                  1045.6         50.050            ✅
# Bucharest                 1295.3         50.050            ✅
# Budapest                  1247.9         50.050            ✅
# Copenhagen                1049.3         50.050            ✅
# Dublin                     985.3         50.050            ✅
# Helsinki                   968.9         50.050            ✅
# Lisbon                    1575.7         50.050            ✅
# Ljubljana                 1168.3         50.050            ✅
# London                    1023.0         50.050            ✅
# ...

# %%
# Out:
#        Country       City  Latitude (°)  Longitude (°)  Yearly AC Energy output ILR 1.0 (MWh)
#        Austria     Vienna       48.2082        16.3738                                  58794
#        Belgium   Brussels       50.8503         4.3517                                  52376
#       Bulgaria      Sofia       42.6977        23.3219                                  65564
#        Croatia     Zagreb       45.8150        15.9819                                  61728
#         Cyprus    Nicosia       35.1856        33.3823                                  81573
# Czech Republic     Prague       50.0755        14.4378                                  54683
#        Denmark Copenhagen       55.6761        12.5683                                  52559
#        Estonia    Tallinn       59.4370        24.7536                                  47502
#        Finland   Helsinki       60.1699        24.9384                                  48534
# ...
